# %% [markdown]
# # NewsAPI

# %% [markdown]
# ### Set Up

# %%
import os
from dotenv import load_dotenv, dotenv_values
from pathlib import Path

# %%
load_dotenv(Path.cwd().parent / ".env")
# Out:
# True

# %%
print(os.getenv("API_KEY_NEWS"))
# Out:
# 5f1946f04b7642ab944af4806cdc7e4b
