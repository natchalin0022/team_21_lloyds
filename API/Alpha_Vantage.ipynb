# %%
import requests
import os
import json
import pandas as pd
from dotenv import load_dotenv, dotenv_values
from requests.exceptions import HTTPError, ConnectionError, Timeout, RequestException
from pathlib import Path

# %%
load_dotenv(Path.cwd().parent / ".env")
# Out:
# True

# %%
URL_BASE = "https://www.alphavantage.co/query?"
TIMEOUT = 10  # seconds

# %%
def get(function="TIME_SERIES_MONTHLY", symbol=None, headers=None):
    url = f"{URL_BASE}"
    response = requests.get(
        url,
        params={
            "function": function,
            "symbol": symbol,
            "apikey": os.getenv("AV_API") 
        },
        timeout=TIMEOUT
        )
    print(response.text)
    response.raise_for_status()
    return response.json()

# %%
get(symbol="IBM")
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Monthly Prices (open, high, low, close) and Volumes",
#         "2. Symbol": "IBM",
#         "3. Last Refreshed": "2026-06-12",
#         "4. Time Zone": "US/Eastern"
#     },
#     "Monthly Time Series": {
#         "2026-06-12": {
#             "1. open": "322.5500",
#             "2. high": "332.4600",
#             "3. low": "266.5000",
#             "4. close": "272.2400",
#             "5. volume": "120737942"
#         },
#         "2026-05-29": {
#             "1. open": "234.5500",
#             "2. high": "300.9999",
#             "3. low": "212.3400",
#             "4. close": "297.8000",
#             "5. volume": "184412168"
#         },
#         "2026-04-30": {
#             "1. open": "242.1200",
#             "2. high": "258.5000",
#             "3. low": "221.7300",
#             "4. close": "230.9800",
#             "5. volume": "133524534"
#         },
#         "2026-03-31": {
# ...

# %%
url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey={os.getenv("AV_KEY")}'
r = requests.get(url)
data = r.json()

data
# Out:
# {'items': '50',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.',
#  'feed': [{'title': 'Why is Traws Pharma stock tumbling today?',
#    'url': 'https://ca.investing.com/news/stock-market-news/why-is-traws-pharma-stock-tumbling-today-93CH-4690251',
#    'time_published': '20260615T104042',
#    'authors': ['Senad Karaahmetovic'],
# ...

# %%
# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = f'https://www.alphavantage.co/query?function=OVERVIEW&symbol=IBM&apikey={os.getenv("AV_KEY")}'
r = requests.get(url)
data = r.json()

data
# Out:
# {'Symbol': 'IBM',
#  'AssetType': 'Common Stock',
#  'Name': 'International Business Machines',
# ...

# %%
url = f'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=LLOY.L&apikey={os.getenv("AV_KEY")}'
r = requests.get(url)
data = r.json()

data
# Out:
# {'Information': 'We have detected your API key as None and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}

# %%
url = f'https://www.alphavantage.co/query?function=BALANCE_SHEET&symbol=LLOY.L&apikey={os.getenv("AV_KEY")}'
r = requests.get(url)
data = r.json()
data
# Out:
# {'Information': 'We have detected your API key as None and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}

# %%
# Nice potential, however this only tracks the comapnies that are listed in the stock
