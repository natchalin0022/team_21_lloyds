# %%
import json

with open("/Users/natchalin_/Desktop/final_project/Lloyds/Data Preprocess/OCR/ocr_results.json") as f:
    data = json.load(f)      # json.load reads a FILE; json.loads reads a STRING

print(type(data))      # dict or list?
len(data)       # how many entries?
# Out:
# <class 'dict'>
# 101
